# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import urllib
import os.path
import re
# !pip install tld
from tld import get_tld
import tldextract
data = pd.read_csv("benign_domain_list.csv")
#data = data[:100]
data
# Out:
# Requirement already satisfied: tld in /Users/edwinmartinez/opt/anaconda3/lib/python3.9/site-packages (0.12.7)
#               Domain
# 0         google.com
# 1       facebook.com
# 2       a-msedge.net
# 3        youtube.com
# 4      microsoft.com
# ...              ...
# 4958    bethesda.net
# 4959  shopifysvc.com
# 4960      instana.io
# 4961       oanda.com
# 4962  skyscanner.com
#
# [4963 rows x 1 columns]

# %%
# I added domain length, uinque counts and actual domain. The unique counts
# does not work so skip that part
domain_list = []
domain_len_list=[]
five_list = []
digit_count_list=[]
unique_count_list = []
tld_list = []
for url in data['Domain']:
    tld = get_tld(url, fix_protocol=True)

    tld_list.append(tld)
    domain = tldextract.extract(url).domain
    domain_list.append(domain)
    domain_len_list.append(len(domain))
    digits_count_domain = [domain.count(x) for x in "1234567890"]
    digit_count_list.append(sum(digits_count_domain))
    unique_count_domain = len(set(domain))
    unique_count_list.append(unique_count_domain)
    if len(domain) >= 1 and len(domain) <= 5:
        five_list.append('1-5')
    elif len(domain) >= 6 and len(domain) <= 10:
        five_list.append('6-10')
    elif len(domain) >= 11 and len(domain) <= 15:
        five_list.append('11-15')
    elif len(domain) >= 16:   
        five_list.append('16')
data['TLD']= tld_list
data['domain_length'] = domain_len_list
data['ActualDomain']= domain_list
data['rank'] = five_list
data['digit_counts']= digit_count_list
data['unique_counts']= unique_count_list
data
# Out:
#               Domain  TLD  domain_length ActualDomain  rank  digit_counts  \
# 0         google.com  com              6       google  6-10             0
# 1       facebook.com  com              8     facebook  6-10             0
# 2       a-msedge.net  net              8     a-msedge  6-10             0
# 3        youtube.com  com              7      youtube  6-10             0
# 4      microsoft.com  com              9    microsoft  6-10             0
# ...              ...  ...            ...          ...   ...           ...
# 4958    bethesda.net  net              8     bethesda  6-10             0
# 4959  shopifysvc.com  com             10   shopifysvc  6-10             0
# 4960      instana.io   io              7      instana  6-10             0
# 4961       oanda.com  com              5        oanda   1-5             0
# 4962  skyscanner.com  com             10   skyscanner  6-10             0
#
#       unique_counts
# 0                 4
# 1                 7
# 2                 7
# 3                 6
# 4                 8
# ...             ...
# 4958              7
# 4959              9
# 4960              5
# 4961              4
# 4962              8
#
# [4963 rows x 7 columns]

# %%
data["TLD"].value_counts()
# Out:
# com              2721
# net               453
# org               313
# ru                149
# edu               116
#                  ...
# id                  1
# ac.at               1
# apple               1
# herokuapp.com       1
# gob.ar              1
# Name: TLD, Length: 270, dtype: int64

# %%
data["unique_counts"].value_counts()
# Out:
# 6     785
# 7     763
# 8     718
# 5     652
# 4     596
# 3     452
# 9     339
# 10    207
# 2     188
# 11    128
# 12     77
# 1      23
# 13     18
# 14     10
# 16      4
# 15      2
# 17      1
# Name: unique_counts, dtype: int64

# %%
#This is to count num of digits in domain
digit_count_list=[]

for url in data['Domain']:
    tld = get_tld(url, fix_protocol=True)
    digit = 0
    tld_list.append(tld)
    domain = tldextract.extract(url).domain
    for s in str(domain):
        if s.isdigit():
            digit=digit+1
    digit_count_list.append(digit)
data['digit_counts']= digit_count_list
data
# Out:
#               Domain  TLD  domain_length ActualDomain  rank  digit_counts  \
# 0         google.com  com              6       google  6-10             0
# 1       facebook.com  com              8     facebook  6-10             0
# 2       a-msedge.net  net              8     a-msedge  6-10             0
# 3        youtube.com  com              7      youtube  6-10             0
# 4      microsoft.com  com              9    microsoft  6-10             0
# ...              ...  ...            ...          ...   ...           ...
# 4958    bethesda.net  net              8     bethesda  6-10             0
# 4959  shopifysvc.com  com             10   shopifysvc  6-10             0
# 4960      instana.io   io              7      instana  6-10             0
# 4961       oanda.com  com              5        oanda   1-5             0
# 4962  skyscanner.com  com             10   skyscanner  6-10             0
#
#       unique_counts
# 0                 4
# 1                 7
# 2                 7
# 3                 6
# 4                 8
# ...             ...
# 4958              7
# 4959              9
# 4960              5
# 4961              4
# 4962              8
#
# [4963 rows x 7 columns]

# %%
# Out:
#                  Domain  TLD  domain_length   ActualDomain   rank  \
# 48    fdv2-t-msedge.net  net             13  fdv2-t-msedge  11-15
# 54              163.com  com              3            163    1-5
# 62        office365.com  com              9      office365   6-10
# 116            gvt1.com  com              4           gvt1    1-5
# 125              w3.org  org              2             w3    1-5
# ...                 ...  ...            ...            ...    ...
# 4907      awsdns-49.org  org              9      awsdns-49   6-10
# 4915   7oc5b1i3v4iu.top  top             12   7oc5b1i3v4iu  11-15
# 4930      awsdns-30.org  org              9      awsdns-30   6-10
# 4945      awsdns-59.net  net              9      awsdns-59   6-10
# 4946          64365.com  com              5          64365    1-5
#
#       digit_counts  unique_counts
# 48               1             10
# 54               3              3
# 62               3              8
# 116              1              4
# 125              1              2
# ...            ...            ...
# 4907             2              8
# 4915             5             11
# 4930             2              8
# 4945             2              8
# 4946             5              4
#
# [458 rows x 7 columns]

# %%
#Top 10 most frequent tlds
top10_tld_df = data['TLD'].value_counts()[0:10];
top10_tld_df.plot(kind='bar');

# %%
# Checks if domain contains any of the substrings listed.
strings = ["amazon","ebay", "google","youtube","apple","mircosoft","walmart","facebook",
             "instagram", "snapchat"]
b = []
count = 0
for url in data['ActualDomain']:
    for s in strings:
        if s in url:
            count = count +1
            b.append(url)
print(count)
data_from_top_ten_tld = data[data['ActualDomain'].isin(b)]
data_from_top_ten_tld
# Out:
# 121
#               Domain     TLD  domain_length ActualDomain  rank  digit_counts  \
# 0         google.com     com              6       google  6-10             0
# 1       facebook.com     com              8     facebook  6-10             0
# 3        youtube.com     com              7      youtube  6-10             0
# 5      amazonaws.com     com              9    amazonaws  6-10             0
# 9      instagram.com     com              9    instagram  6-10             0
# ...              ...     ...            ...          ...   ...           ...
# 4631       google.pt      pt              6       google  6-10             0
# 4850       google.fi      fi              6       google  6-10             0
# 4866       google.dk      dk              6       google  6-10             0
# 4908       google.no      no              6       google  6-10             0
# 4928  walmart.com.mx  com.mx              7      walmart  6-10             0
#
#       unique_counts
# 0                 4
# 1                 7
# 3                 6
# 5                 7
# 9                 8
# ...             ...
# 4631              4
# 4850              4
# 4866              4
# 4908              4
# 4928              6
#
# [121 rows x 7 columns]

# %%
data_rank = pd.read_csv("Tranco_ranking.csv")
data_rank
# Out:
#           TLD  Score
# 0         aaa   0.00
# 1         abb   0.00
# 2      abbott   0.00
# 3      abbvie   0.00
# 4         abc   0.00
# ...       ...    ...
# 996       zip   0.00
# 997        zm   0.00
# 998      zone   0.84
# 999   zuerich   0.00
# 1000       zw   0.00
#
# [1001 rows x 2 columns]

# %%
new_merged_df = pd.merge(data, data_rank, on=['TLD'])
new_merged_df
# Out:
#              Domain   TLD  domain_length ActualDomain  rank  digit_counts  \
# 0        google.com   com              6       google  6-10             0
# 1      facebook.com   com              8     facebook  6-10             0
# 2       youtube.com   com              7      youtube  6-10             0
# 3     microsoft.com   com              9    microsoft  6-10             0
# 4     amazonaws.com   com              9    amazonaws  6-10             0
# ...             ...   ...            ...          ...   ...           ...
# 4598         itv.kg    kg              3          itv   1-5             0
# 4599    teleport.sh    sh              8     teleport  6-10             0
# 4600    hostia.name  name              6       hostia  6-10             0
# 4601       csiro.au    au              5        csiro   1-5             0
# 4602        tool.lu    lu              4         tool   1-5             0
#
#       unique_counts  Score
# 0                 4   0.17
# 1                 7   0.17
# 2                 6   0.17
# 3                 8   0.17
# 4                 7   0.17
# ...             ...    ...
# 4598              3   0.00
# 4599              6   0.03
# 4600              6   0.76
# 4601              5   0.00
# 4602              3   0.00
#
# [4603 rows x 8 columns]

# %%
#Visual to show mediam, mean,etc
import seaborn as sns
sns.boxplot(x= new_merged_df['Score'], showmeans=True);

# %%
#Actual average listed
new_merged_df.describe()
# Out:
#        domain_length  digit_counts  unique_counts        Score
# count    4603.000000   4603.000000    4603.000000  4603.000000
# mean        7.570715      0.162937       6.320660     0.145275
# std         3.335953      0.588126       2.399329     0.149348
# min         1.000000      0.000000       1.000000     0.000000
# 25%         5.000000      0.000000       5.000000     0.070000
# 50%         7.000000      0.000000       6.000000     0.170000
# 75%         9.000000      0.000000       8.000000     0.170000
# max        26.000000      5.000000      17.000000     3.950000

# %%
data2 = pd.read_csv("mixed_domain_list.csv")
data2
# Out:
#                                   Domain
# 0                             goodrx.com
# 1                         weather.com.cn
# 2                         draftkings.com
# 3                           suntimes.com
# 4                             moe.gov.cn
# ..                                   ...
# 178         services.runescape.com-ul.cc
# 179                  nsu-amazon.1inc.top
# 180                            80fxv9.cn
# 181                  nsu-amazon.3inc.top
# 182  hmcb-crad.com-men-indxe.iilgbxka.cn
#
# [183 rows x 1 columns]

# %%
digit_count_list=[]
tld_list = []
for url in data2['Domain']:
    tld = get_tld(url, fix_protocol=True)
    digit = 0
    tld_list.append(tld)
    domain = tldextract.extract(url).domain
    for s in str(domain):
        if s.isdigit():
            digit=digit+1
    digit_count_list.append(digit)
data2['digit_counts']= digit_count_list
data2
# Out:
#                                   Domain  digit_counts
# 0                             goodrx.com             0
# 1                         weather.com.cn             0
# 2                         draftkings.com             0
# 3                           suntimes.com             0
# 4                             moe.gov.cn             0
# ..                                   ...           ...
# 178         services.runescape.com-ul.cc             0
# 179                  nsu-amazon.1inc.top             1
# 180                            80fxv9.cn             3
# 181                  nsu-amazon.3inc.top             1
# 182  hmcb-crad.com-men-indxe.iilgbxka.cn             0
#
# [183 rows x 2 columns]

# %%
domain_list = []
domain_len_list=[]
five_list = []
digit_count_list=[]
unique_count_list = []
tld_list = []
for url in data2['Domain']:
    tld = get_tld(url, fix_protocol=True)

    tld_list.append(tld)
    domain = tldextract.extract(url).domain
    domain_list.append(domain)
    domain_len_list.append(len(domain))
    digits_count_domain = [domain.count(x) for x in "1234567890"]
    digit_count_list.append(sum(digits_count_domain))
    unique_count_domain = len(set(domain))
    unique_count_list.append(unique_count_domain)
    if len(domain) >= 1 and len(domain) <= 5:
        five_list.append('1-5')
    elif len(domain) >= 6 and len(domain) <= 10:
        five_list.append('6-10')
    elif len(domain) >= 11 and len(domain) <= 15:
        five_list.append('11-15')
    elif len(domain) >= 16:   
        five_list.append('16')
data2['TLD']= tld_list
data2['domain_length'] = domain_len_list
data2['ActualDomain']= domain_list
data2['rank'] = five_list
data2['digit_counts']= digit_count_list
data2['unique_counts']= unique_count_list
data2
# Out:
#                                   Domain  digit_counts     TLD  domain_length  \
# 0                             goodrx.com             0     com              6
# 1                         weather.com.cn             0  com.cn              7
# 2                         draftkings.com             0     com             10
# 3                           suntimes.com             0     com              8
# 4                             moe.gov.cn             0  gov.cn              3
# ..                                   ...           ...     ...            ...
# 178         services.runescape.com-ul.cc             0      cc              6
# 179                  nsu-amazon.1inc.top             1     top              4
# 180                            80fxv9.cn             3      cn              6
# 181                  nsu-amazon.3inc.top             1     top              4
# 182  hmcb-crad.com-men-indxe.iilgbxka.cn             0      cn              8
#
#     ActualDomain  rank  unique_counts
# 0         goodrx  6-10              5
# 1        weather  6-10              6
# 2     draftkings  6-10             10
# 3       suntimes  6-10              7
# 4            moe   1-5              3
# ..           ...   ...            ...
# 178       com-ul  6-10              6
# 179         1inc   1-5              4
# 180       80fxv9  6-10              6
# 181         3inc   1-5              4
# 182     iilgbxka  6-10              7
#
# [183 rows x 7 columns]

# %%
new_merged_df2 = pd.merge(data2, data_rank, on=['TLD'])
new_merged_df2
# Out:
#                                 Domain  digit_counts   TLD  domain_length  \
# 0                           goodrx.com             0   com              6
# 1                       draftkings.com             0   com             10
# 2                         suntimes.com             0   com              8
# 3                             nate.com             0   com              4
# 4                              nme.com             0   com              3
# ..                                 ...           ...   ...            ...
# 165                               t.me             0    me              1
# 166               freedomforukraine.co             0    co             17
# 167  annzon-xudtgfl-co-jp.wizmghd.buzz             0  buzz              7
# 168                nsu-amazon.1inc.top             1   top              4
# 169                nsu-amazon.3inc.top             1   top              4
#
#           ActualDomain  rank  unique_counts  Score
# 0               goodrx  6-10              5   0.17
# 1           draftkings  6-10             10   0.17
# 2             suntimes  6-10              7   0.17
# 3                 nate   1-5              4   0.17
# 4                  nme   1-5              3   0.17
# ..                 ...   ...            ...    ...
# 165                  t   1-5              1   0.08
# 166  freedomforukraine    16             11   0.09
# 167            wizmghd  6-10              7   0.25
# 168               1inc   1-5              4   1.74
# 169               3inc   1-5              4   1.74
#
# [170 rows x 8 columns]

# %%
score_list = []
import seaborn as sns
for index,url in new_merged_df2.iterrows():
    score = 0
    if url['unique_counts'] >= 7:
        score += 1
    if url['digit_counts'] >= 2.5:
        score += 1
    if url['domain_length'] >= 9:
        score += 1
    if url['Score'] >= .15:
        score += 1
    score_list.append(score)
new_merged_df2['MalScore'] = score_list
new_merged_df2
# Out:
#                                 Domain  digit_counts   TLD  domain_length  \
# 0                           goodrx.com             0   com              6
# 1                       draftkings.com             0   com             10
# 2                         suntimes.com             0   com              8
# 3                             nate.com             0   com              4
# 4                              nme.com             0   com              3
# ..                                 ...           ...   ...            ...
# 165                               t.me             0    me              1
# 166               freedomforukraine.co             0    co             17
# 167  annzon-xudtgfl-co-jp.wizmghd.buzz             0  buzz              7
# 168                nsu-amazon.1inc.top             1   top              4
# 169                nsu-amazon.3inc.top             1   top              4
#
#           ActualDomain  rank  unique_counts  Score  MalScore
# 0               goodrx  6-10              5   0.17         1
# 1           draftkings  6-10             10   0.17         3
# 2             suntimes  6-10              7   0.17         2
# 3                 nate   1-5              4   0.17         1
# 4                  nme   1-5              3   0.17         1
# ..                 ...   ...            ...    ...       ...
# 165                  t   1-5              1   0.08         0
# 166  freedomforukraine    16             11   0.09         2
# 167            wizmghd  6-10              7   0.25         2
# 168               1inc   1-5              4   1.74         1
# 169               3inc   1-5              4   1.74         1
#
# [170 rows x 9 columns]

# %%
new_merged_df2[(new_merged_df2['MalScore'] >= 2)]
# Out:
#                                 Domain  digit_counts      TLD  domain_length  \
# 1                       draftkings.com             0      com             10
# 2                         suntimes.com             0      com              8
# 6                        awsdns-12.com             2      com              9
# 7                       localytics.com             0      com             10
# 8                          porsche.com             0      com              7
# ..                                 ...           ...      ...            ...
# 162                 housing-ukraine.be             0       be             15
# 163              artforukraine.gallery             0  gallery             13
# 164              leiriahelpsukraine.pt             0       pt             18
# 166               freedomforukraine.co             0       co             17
# 167  annzon-xudtgfl-co-jp.wizmghd.buzz             0     buzz              7
#
#            ActualDomain   rank  unique_counts  Score  MalScore
# 1            draftkings   6-10             10   0.17         3
# 2              suntimes   6-10              7   0.17         2
# 6             awsdns-12   6-10              8   0.17         3
# 7            localytics   6-10              8   0.17         3
# 8               porsche   6-10              7   0.17         2
# ..                  ...    ...            ...    ...       ...
# 162     housing-ukraine  11-15             12   0.01         2
# 163       artforukraine  11-15             10   0.00         2
# 164  leiriahelpsukraine     16             11   0.00         2
# 166   freedomforukraine     16             11   0.09         2
# 167             wizmghd   6-10              7   0.25         2
#
# [102 rows x 9 columns]

# %%
Danger_list = ['Low Risk', 'Mild Risk','Moderate Risk', 'High Risk', 'Extreme Risk']
 
data = [23, 17, 35, 29, 12, 41]
score0 = 0
score1= 0
score2 = 0
score3 = 3
score4 = 0
for index,url in new_merged_df2.iterrows():
    score = 0
    if url['MalScore'] == 0:
        score0 += 1
    if url['MalScore'] == 1:
        score1 += 1
    if url['MalScore'] == 2:
        score2 += 1
    if url['MalScore'] == 3:
        score3 += 1
    if url['MalScore'] == 4:
        score4 += 1
score_list = [score0,score1,score2,score3,score4]
plt.pie(score_list, labels = Danger_list)
 

plt.show()
 
plt.show()
print(score2+ score3 + score4)
# Out:
# 105
